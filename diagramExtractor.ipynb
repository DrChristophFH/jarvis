# %%
import os
import re

class ClassDetails:
    def __init__(self, name, extends=None, implements=None):
        self.name = name
        self.extends = extends
        self.implements = implements
        self.members = []
        self.methods = []

    def add_member(self, member):
        modifier = member[0]
        type = member[1]
        name = member[2]
        if modifier == "public":
            modifier = "+"
        elif modifier == "private":
            modifier = "-"
        elif modifier == "protected":
            modifier = "#"
        self.members.append(f"{modifier} {name}: {type}")

    def add_method(self, method):
        modifier = method[0]
        type = method[1]
        name = method[2]
        if modifier == "public":
            modifier = "+"
        elif modifier == "private":
            modifier = "-"
        elif modifier == "protected":
            modifier = "#"
        self.methods.append(f"{modifier} {name}(): {type}")

    def __str__(self):
        class_header = f"{self.name}"
        if self.extends or self.implements:
            class_header += " :"
            if self.extends:
                class_header += f" extends {self.extends}"
            if self.implements:
                class_header += f" implements {self.implements}"
        # sort members and methods
        self.members.sort()
        self.methods.sort()

        member_str = "\n".join(self.members)
        method_str = "\n".join(self.methods)
        return f"{class_header}\n{member_str}\n--\n{method_str}\n"

def parse_java_file(file_path):
    with open(file_path, 'r') as file:
        content = file.read()

        # Extract class details
        class_match = re.search(r'public class (\w+)(?: extends (\w+))?(?: implements (\w+))?', content)
        if not class_match:
            return None

        class_name = class_match.group(1)
        extends = class_match.group(2)
        implements = class_match.group(3)
        class_details = ClassDetails(class_name, extends, implements)

        # Extract members and methods
        members = re.findall(r'(private|public|protected) ((?!class\b)\b\w+) (\b\w+\b(?!\())', content)
        methods = re.findall(r'(private|public|protected) ((?!class\b)\b\w+) (\b\w+\b(?=\())', content)
        
        for member in members:
            class_details.add_member(member)
        for method in methods:
            class_details.add_method(method)

        return class_details

def crawl_java_project(project_path):
    all_classes = []
    for root, dirs, files in os.walk(project_path):
        for file in files:
            if file.endswith(".java"):
                file_path = os.path.join(root, file)
                class_details = parse_java_file(file_path)
                if class_details:
                    all_classes.append(class_details)
    return all_classes

# %%
project_path = "src/"  # Update this path
classes = crawl_java_project(project_path)
for class_detail in classes:
  print(class_detail)
# Out:
# Display
#
# --
# + print(): void
#
# HashMap
# - class: static
# - currentIndex: int
# - index: int
# - maxLoadFactor: float
# - size: int
# --
# + clear(): void
# + containsKey(): boolean
# + containsValue(): boolean
# + get(): V
# + getLoadFactor(): float
# + getMaxLoadFactor(): float
# + hasNext(): boolean
# + isEmpty(): boolean
# + put(): V
# + rehash(): void
# + remove(): V
# + remove(): void
# + size(): int
# - hash(): int
# - updateReferences(): void
#
# JDIExampleDebuggee
# + void: static
# + void: static
# --
#
#
# KeyValuePair
# - key: K
# - value: V
# --
# + equals(): boolean
# + getKey(): K
# + getValue(): V
#
# Robot
# + isAlive: boolean
# + name: String
# - Display: final
# - x: int
# - y: int
# - z: int
# --
# + howAreYou(): void
# + move(): void
# + toString(): String
# + whereAreYou(): void
#
# UberRobot : extends Robot
# - lel: String
# --
#
#
# Application
# # handle: long
# # void: final
# # void: final
# # void: final
# + long: final
# + void: static
# - ImGuiImplGl3: final
# - ImGuiImplGlfw: final
# - glslVersion: String
# --
# # disposeImGui(): void
# # disposeWindow(): void
# # endFrame(): void
# # initImGui(): void
# # initWindow(): void
# # postProcess(): void
# # postRun(): void
# # preProcess(): void
# # preRun(): void
# # startFrame(): void
# + process(): void
# - decideGlGlslVersions(): void
#
# Bounder
# - bound: Vec2
# - offset: Vec2
# --
# + addOffset(): void
# + addX(): void
# + addY(): void
# + bound(): void
# + boundX(): void
# + boundY(): void
# + getBound(): Vec2
# + subtractOffset(): void
#
# Colors
# + final: static
# + final: static
# + final: static
# + final: static
# + final: static
# + final: static
# --
#
#
# Configuration
# - fullScreen: boolean
# - height: int
# - title: String
# - width: int
# --
# + getHeight(): int
# + getTitle(): String
# + getWidth(): int
# + isFullScreen(): boolean
# + setFullScreen(): void
# + setHeight(): void
# + setTitle(): void
# + setWidth(): void
#
# Draw
# - ImDrawList: final
# - offset: Vec2
# - scroll: Vec2
# --
# + absolute(): Vec2
# + addCircle(): void
# + addCircleFilled(): void
# + addLine(): void
# + addRect(): void
# + addRect(): void
# + addRectB(): void
# + addRectFilled(): void
# + addText(): void
# + boundersAddOffset(): void
# + boundersSubtractOffset(): void
# + calcBoundStack(): void
# + popBounder(): Vec2
# + popClipRect(): void
# + popOffset(): void
# + pushBounder(): void
# + pushClipRect(): void
# + pushOffset(): void
# + setScroll(): void
#
# Vec2
# + x: float
# + y: float
# --
# + add(): Vec2
# + add(): Vec2
# + add(): Vec2
# + add(): Vec2
# + addDirection(): Vec2
# + clampAbs(): Vec2
# + clear(): Vec2
# + scale(): Vec2
# + scaleX(): Vec2
# + scaleY(): Vec2
# + set(): Vec2
# + subtract(): Vec2
# + subtract(): Vec2
# + subtract(): Vec2
# + subtract(): Vec2
# + toString(): String
#
# Main : extends Application
# + void: static
# --
# # preRun(): void
# + process(): void
#
# JarvisDebugger
# - BreakPointProvider: final
# - DebugeeConsole: final
# - Log: final
# - callStackModel: CallStackModel
# - classPath: String
# - mainClass: String
# - objectGraphModel: ObjectGraphModel
# - vm: VirtualMachine
# --
# + executeCommand(): void
# + getClassPath(): String
# + getMainClass(): String
# + launch(): void
# + setCallStackModel(): void
# + setClassPath(): void
# + setMainClass(): void
# + setObjectGraphModel(): void
# + shutdown(): void
# - connectAndLaunchVM(): void
# - debug(): void
# - enableClassPrepareRequest(): void
# - enableExceptionRequest(): void
# - handleInput(): void
# - processUserCommand(): void
# - setBreakPoints(): void
# - startDebugging(): void
# - startStreamThread(): void
# - waitForUserCommand(): StepCommand
#
# GraphLayouter : implements Observer
# - dampingFactor: float
# - gravityForce: float
# - idealSpringLength: int
# - idealSpringLengthRoot: int
# - isLayoutStable: boolean
# - layoutRootsManually: boolean
# - maxVelocity: int
# - random: Random
# - repulsionForce: int
# - springForce: float
# - springForceRoot: float
# - threshold: float
# --
# + getDampingFactor(): float
# + getGravityForce(): float
# + getIdealSpringLength(): int
# + getIdealSpringLengthRoot(): int
# + getLayoutRootsManually(): boolean
# + getMaxVelocity(): int
# + getRepulsionForce(): int
# + getSpringForce(): float
# + getSpringForceRoot(): float
# + getThreshold(): float
# + isLayoutStable(): boolean
# + layoutRunner(): void
# + setDampingFactor(): void
# + setGravityForce(): void
# + setIdealSpringLength(): void
# + setIdealSpringLengthRoot(): void
# + setLayoutRootsManually(): void
# + setMaxVelocity(): void
# + setRepulsionForce(): void
# + setSpringForce(): void
# + setSpringForceRoot(): void
# + setThreshold(): void
# + update(): void
# - calcRepulsionForce(): Vec2
# - calcSpringForce(): Vec2
# - layoutNodes(): void
# - layoutRoots(): void
#
# LayoutableEdgeImpl : implements LayoutableEdge
# - source: LayoutableNode
# - target: LayoutableNode
# --
# + getSource(): LayoutableNode
# + getTarget(): LayoutableNode
#
# OGMTransformer : implements Observer
# - ogm: ObjectGraphModel
# - recalcWidths: boolean
# --
# + recalcWidthsIfNecessary(): void
# + transform(): void
# + update(): void
#
# RendererRegistry
#
# --
# + setFieldRenderer(): void
#
# SimpleFieldRenderer : extends Renderer
#
# --
# + render(): void
#
# SimpleLocalVariableRenderer : extends Renderer
#
# --
# + render(): void
#
# SimpleObjectNodeRenderer : extends Renderer
#
# --
# + render(): void
#
# SimplePrimitiveRenderer : extends Renderer
#
# --
# + render(): void
#
# BinaryRenderer : extends Renderer
#
# --
# + isApplicable(): boolean
# + render(): void
#
# CallStackModel
#
# --
# + clear(): void
# + syncWith(): void
#
# InteractionState
# - selectedObjectId: long
# --
# + getSelectedObjectId(): long
# + setSelectedObjectId(): void
#
# ObjectGraphModel : implements Observable
# - List: final
# - Map: final
# - Map: final
# - currentThread: ThreadReference
# --
# + addObserver(): void
# + clear(): void
# + getLocalVariable(): LocalGVariable
# + notifyObservers(): void
# + removeObserver(): void
# + syncWith(): void
# - addLocalVariable(): void
# - createArrayNode(): ObjectGNode
# - createContentGVariable(): ContentGVariable
# - createMemberGVariable(): MemberGVariable
# - createObjectNode(): ObjectGNode
# - createPrimitiveNode(): GNode
# - lookUpObjectNode(): ObjectGNode
# - removeObject(): void
# - resolveToString(): String
# - updateContents(): void
# - updateMembers(): void
# - updateVariable(): void
#
# AccessModifier
# - int: final
# --
# + getNumber(): int
# + isEnum(): boolean
# + isFinal(): boolean
# + isPrivate(): boolean
# + isProtected(): boolean
# + isPublic(): boolean
# + isStatic(): boolean
# + isSynthetic(): boolean
# + isTransient(): boolean
# + isVolatile(): boolean
# + toString(): String
#
# CallStackFrame
# - classType: Type
# - lineNumber: int
# - method: Method
# - stackFrame: StackFrame
# --
# + getClassType(): Type
# + getFullMethodHeader(): String
# + getLineNumber(): int
# + getMethod(): Method
# + getStackFrame(): StackFrame
#
# ArrayGNode : extends ObjectGNode
# - List: final
# --
# + addContent(): void
#
# ContentGVariable : extends GVariable
# - ObjectGNode: final
# - int: final
# --
# + getContainingObject(): ObjectGNode
# + getIndex(): int
#
# GVariable
# + getStaticSimpleType: String
# - name: String
# - node: GNode
# - staticType: Type
# --
# + equals(): boolean
# + getName(): String
# + getNode(): GNode
# + getStaticType(): Type
# + hashCode(): int
# + setNode(): void
#
# LocalGVariable : extends GVariable implements LayoutableNode
# - StackFrameInformation: final
# - frozen: boolean
# - layouted: boolean
# - length: int
# - localVariable: LocalVariable
# - nodeId: int
# - position: Vec2
# - velocity: Vec2
# --
# + getLength(): int
# + getLocalVariable(): LocalVariable
# + getNodeId(): int
# + getPosition(): Vec2
# + getStackFrameInformation(): StackFrameInformation
# + getVelocity(): Vec2
# + isFrozen(): boolean
# + isLayouted(): boolean
# + setFrozen(): void
# + setLength(): void
# + setNodeId(): void
# + setPosition(): void
# + setVelocity(): void
#
# MemberGVariable : extends GVariable
# - AccessModifier: final
# - Field: final
# - ObjectGNode: final
# --
# + getAccessModifier(): AccessModifier
# + getAccessModifierNumber(): int
# + getContainingObject(): ObjectGNode
# + getField(): Field
#
# ObjectGNode : extends GNode implements LayoutableNode
# - List: final
# - List: final
# - frozen: boolean
# - layouted: boolean
# - length: int
# - long: final
# - nodeId: int
# - position: Vec2
# - toStringRepresentation: String
# - velocity: Vec2
# --
# + addMember(): void
# + addReferenceHolder(): void
# + getLength(): int
# + getNodeId(): int
# + getObjectId(): long
# + getPosition(): Vec2
# + getToString(): String
# + getVelocity(): Vec2
# + isFrozen(): boolean
# + isLayouted(): boolean
# + removeReferenceHolder(): void
# + setFrozen(): void
# + setLength(): void
# + setNodeId(): void
# + setPosition(): void
# + setToString(): void
# + setVelocity(): void
#
# PrimitiveGNode : extends GNode
# - PrimitiveValue: final
# --
# + getPrimitiveValue(): PrimitiveValue
#
# StackFrameInformation
#
# --
#
#
# Snippets
# + String: static
# + void: static
# + void: static
# + void: static
# --
#
#
# TypeFormatter
# + String: static
# --
#
#
# BreakPointControl : extends View implements BreakPointProvider
# - classPath: String
# - line: ImInt
# - selected: String
# --
# # renderWindow(): void
# + setClassPath(): void
# - processDirectory(): void
# - processJarFile(): void
# - refresh(): void
#
# CallStack : extends View
# - model: CallStackModel
# --
# # renderWindow(): void
# + getCallStackModel(): CallStackModel
# - showParameters(): void
#
# Console : extends View implements DebugeeConsole
# - autoScroll: boolean
# - inputBuf: ImString
# - inputHandler: InputHandler
# - scrollToBottom: boolean
# --
# # renderWindow(): void
# + println(): void
# + registerInputHandler(): void
# - clearLog(): void
#
# DebugStepControl : extends View
# + CommandExecutor: interface
# - executor: CommandExecutor
# --
# # renderWindow(): void
# + render(): void
# + setCommandExecutor(): void
#
# Jarvis
# - Application: final
# - String: final
# - breakPointControl: BreakPointControl
# - callStack: CallStack
# - classPath: ImString
# - console: Console
# - debugStepControl: DebugStepControl
# - eventLog: Log
# - interactionState: InteractionState
# - jarvisDebugger: JarvisDebugger
# - layouterControl: LayouterControl
# - localVarList: LocalVarList
# - mainClass: ImString
# - objectGraph: ObjectGraph
# - objectList: ObjectList
# --
# + render(): void
# - HelpSection(): void
# - JarvisConfig(): void
#
# LayouterControl : extends View
# - layouter: GraphLayouter
# --
# # renderWindow(): void
#
# LocalVarList : extends View
# - iState: InteractionState
# - model: ObjectGraphModel
# --
# # renderWindow(): void
# + setObjectGraphModel(): void
# - showLocalVarsTable(): void
#
# Log : extends View
# - autoScroll: ImBoolean
# - filter: ImGuiTextFilter
# --
# # renderWindow(): void
# + accept(): void
# + log(): void
# + render(): void
#
# ObjectGraph : extends View
# - layouter: GraphLayouter
# - model: ObjectGraphModel
# - rendererRegistry: RendererRegistry
# - transformer: OGMTransformer
# --
# # renderWindow(): void
# + getLayouter(): GraphLayouter
# + getObjectGraphModel(): ObjectGraphModel
# + render(): void
# - drawGraph(): void
#
# ObjectList : extends View
# - iState: InteractionState
# - model: ObjectGraphModel
# --
# # renderWindow(): void
# + setObjectGraphModel(): void
# - displayObject(): void
# - displayPrimitive(): void
# - showObjectsTable(): void
